# %%
#Implementing a half adder circuit

from qiskit.circuit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit import transpile

qc=QuantumCircuit(4,4)

# A=0 B=1 S=2 C=3
qc.cx(0,2) # If A then toggle S
qc.cx(1,2) # If B then toggle S
qc.ccx(0,1,3) #If A & B then toggle C

qc.draw('mpl')

# %%
#Implementing a half adder circuit

from qiskit.circuit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit import transpile

qc=QuantumCircuit(4,4)

# A=0 B=1 S=2 C=3
qc.x(0) # Set A=1
qc.x(1) # Set B=1

qc.cx(0,2) # If A then toggle S
qc.cx(1,2) # If B then toggle S
qc.ccx(0,1,3) #If A & B then toggle C

qc.measure(range(4), range(4)) 

sim=AerSimulator()
qc_transpiled=transpile(qc,sim)
result=sim.run(qc_transpiled,shots=1024).result()
counts=result.get_counts()
print("Result = ", counts)
# Out:
# Result =  {'1011': 1024}

# %%
# Implementing half subtractor circuit

from qiskit.circuit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit import transpile

qc=QuantumCircuit(4,4)

# A=0 B=1 D=2 Bout=3
qc.x(0) # Set A=1
qc.x(1) # Set B=1

qc.cx(0,2) # If A then toggle D
qc.cx(1,2) # If B then toggle D
qc.x(0) # Toggle A
qc.ccx(0,1,3) #If A & B then toggle Bout
qc.x(0) # Toggle A 

qc.draw('mpl')

# %%
# Implementing a half subtractor circuit

from qiskit.circuit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit import transpile

qc=QuantumCircuit(4,4)

# A=0 B=1 D=2 Bout=3
qc.x(0) # Set A=1
qc.x(1) # Set B=1

qc.cx(0,2) # If A then toggle D
qc.cx(1,2) # If B then toggle D
qc.x(0) # Toggle A
qc.ccx(0,1,3) #If A & B then toggle Bout
qc.x(0) # Toggle A 

qc.measure(range(4), range(4))
sim=AerSimulator()
qc_transpiled=transpile(qc,sim)
result=sim.run(qc_transpiled,shots=1024).result()
counts=result.get_counts()
print("Result = ", counts)
# Out:
# Result =  {'0011': 1024}
